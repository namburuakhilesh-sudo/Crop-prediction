# %% [markdown]
# <a href="https://colab.research.google.com/github/namburuakhilesh-sudo/Crop-prediction/blob/main/C_V_LAB_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# Load the image in grayscale
img = cv2.imread('/content/ferrari.jpg',cv2.IMREAD_GRAYSCALE)
if img is None:
    print('Error loading image')
else:
  plt.figure(figsize=(12,10))
  # Display Original Image
  plt.subplot(3,3,1)
  plt.imshow(img, cmap='gray')
  plt.title('Original Image')
  plt.axis('off')
for i in range(8):
  bit_plane=(img>>i)&1
  bit_plane=bit_plane*255
  plt.subplot(3,3,i+2)
  plt.imshow(bit_plane, cmap='gray')
  plt.title(f'Bit Plane {i+1}')
  plt.axis('off')
plt.tight_layout()
plt.show()
